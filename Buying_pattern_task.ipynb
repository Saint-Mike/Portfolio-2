# %% [markdown]
# # Задание 1
# В файле содержится информация о покупках людей:
#
# * **id** – означает покупку (в одну покупку входят все товары, купленные пользователем во время 1 похода в магазин)
# * **Товар** – наименование товара
# * **Количество** – число единиц купленного товара
#
# Воспользуйтесь этими данными и выясните, какие пары товаров пользователи чаще всего покупают вместе.
# Напишите код на **python** для получения нужной таблицы и укажите **5** наиболее распространённых паттернов.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Открытие csv-файла и проверка датафрейма

# %%
df = pd.read_csv('test1_completed.csv')

# %%
df.head()
# Out:
#       id            Товар  Количество
# 0  17119            Лимон         1.1
# 1  17119  Лимон оранжевый         0.7
# 2  17119        Лук-порей        10.0
# 3  17119     Лук репчатый         2.5
# 4  17119    Малина свежая         1.0

# %% [markdown]
# Проверяем датафрейм на наличие повторов и отсутствующих значений:

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isna().sum()
# Out:
# id            0
# Товар         0
# Количество    0
# dtype: int64

# %% [markdown]
# Смотрим на минимальное **'Количество'** приобретаемых товаров:

# %%
df['Количество'].min()
# Out:
# 0.1

# %% [markdown]
# Для определения паттернов встречаемости, количество товара в чеке неважно. Примем '**Количество**' = 1, для определения наличия товара в чеке:

# %%
df['Количество'] = 1

# %% [markdown]
# Для определения наиболее популярных пар товаров в чеке, удобно использовать сводные таблицы.

# %% [markdown]
# ### Создание Pivot table и определение паттерна покупок.

# %% [markdown]
# Создадим сводную таблицу, в которой **index =** 'id чека', **columns =** 'Товар', **values =** 'встречаемость товара в чеке' и заполним пустые строки **NaN** нулями:

# %%
pivot_1 = df.pivot_table(index='Товар', columns='id', values='Количество', fill_value=0)

# %% [markdown]
# Руководствуюясь свойствами матриц, определим наиболее популярные пары товаров. Для этого создадим транспонированную матрицу **pivot_2**, а затем перемножим получившиеся сводные таблицы:

# %%
pivot_2=pivot_1.T

# %%
pair_pivot=pivot_1.dot(pivot_2)

# %%
pair_pivot
# Out:
# Товар                Абрикос вяленый  Абрикосы молдавские  Авокадо ХАСС  \
# Товар
# Абрикос вяленый                  111                   20            10
# Абрикосы молдавские               20                  471            37
# Авокадо ХАСС                      10                   37           227
# Авокадо стандарт                  14                   46            25
# Алыча вяленая                      6                   23             7
# ...                              ...                  ...           ...
# Яблоки Фуджи                       5                   26            19
# Яблоки Чемпион                     5                   27            17
# Яблоки сезонные                    5                   23            13
# Яблоки сушеные                     7                   18            14
# Ягоды Годжи                        7                   29            16
#
# Товар                Авокадо стандарт  Алыча вяленая  Ананас Gold  \
# Товар
# Абрикос вяленый                    14              6            5
# Абрикосы молдавские                46             23           23
# Авокадо ХАСС                       25              7           15
# Авокадо стандарт                  238             14           18
# Алыча вяленая                      14            142            9
# ...                               ...            ...          ...
# Яблоки Фуджи                       17              9            6
# Яблоки Чемпион                     18              9            9
# Яблоки сезонные                    15              9           10
# Яблоки сушеные                      9             13            5
# Ягоды Годжи                        18              8            6
#
# Товар                Ананасовые кольца  Апельсины столовые  Арбуз  \
# Товар
# Абрикос вяленый                      7                  14     42
# Абрикосы молдавские                 19                  48    141
# Авокадо ХАСС                        18                  32     80
# Авокадо стандарт                    15                  31     86
# Алыча вяленая                        9                  23     41
# ...                                ...                 ...    ...
# Яблоки Фуджи                         9                  15     48
# Яблоки Чемпион                       9                  18     41
# Яблоки сезонные                     12                  22     52
# Яблоки сушеные                       3                   7     31
# Ягоды Годжи                          6                  15     47
#
# Товар                Арбуз овальный  ...  Яблоки Гала  Яблоки Голден  \
# Товар                                ...
# Абрикос вяленый                   7  ...           12              4
# Абрикосы молдавские              37  ...           30             26
# Авокадо ХАСС                     16  ...           14             16
# Авокадо стандарт                 14  ...           16             20
# Алыча вяленая                     9  ...            9              6
# ...                             ...  ...          ...            ...
# Яблоки Фуджи                     14  ...           11             11
# Яблоки Чемпион                   14  ...           13             11
# Яблоки сезонные                  10  ...           16              8
# Яблоки сушеные                    6  ...            5              6
# Ягоды Годжи                       9  ...            7              8
#
# Товар                Яблоки Джонаголд  Яблоки Мутсу  Яблоки Симиренко  \
# Товар
# Абрикос вяленый                     9             3                 9
# Абрикосы молдавские                29            23                35
# Авокадо ХАСС                       15            14                19
# Авокадо стандарт                   11            18                16
# Алыча вяленая                      11            10                 5
# ...                               ...           ...               ...
# Яблоки Фуджи                       13            13                22
# Яблоки Чемпион                     11             7                11
# Яблоки сезонные                     3             7                10
# Яблоки сушеные                     10             9                 6
# Ягоды Годжи                        13             6                12
#
# Товар                Яблоки Фуджи  Яблоки Чемпион  Яблоки сезонные  \
# Товар
# Абрикос вяленый                 5               5                5
# Абрикосы молдавские            26              27               23
# Авокадо ХАСС                   19              17               13
# Авокадо стандарт               17              18               15
# Алыча вяленая                   9               9                9
# ...                           ...             ...              ...
# Яблоки Фуджи                  156              10                5
# Яблоки Чемпион                 10             144               10
# Яблоки сезонные                 5              10              144
# Яблоки сушеные                 10               7                8
# Ягоды Годжи                     8              11               11
#
# Товар                Яблоки сушеные  Ягоды Годжи
# Товар
# Абрикос вяленый                   7            7
# Абрикосы молдавские              18           29
# Авокадо ХАСС                     14           16
# Авокадо стандарт                  9           18
# Алыча вяленая                    13            8
# ...                             ...          ...
# Яблоки Фуджи                     10            8
# Яблоки Чемпион                    7           11
# Яблоки сезонные                   8           11
# Яблоки сушеные                  119            7
# Ягоды Годжи                       7          160
#
# [199 rows x 199 columns]

# %% [markdown]
# Мы получили частоту встречаемости каждой пары товаров в чеке, теперь решим проблему дублирования результатов относительно диагонали.

# %% [markdown]
# ###  Фильтрация паразитных значений

# %% [markdown]
# Создадим маску для ненужных нам значений. Для этого воспользуемся методом **triu()** библиотеки **numpy**, он позволит преобразовать нижний треугольник относительно диагонали в **0**, затем обернем значения в тип данных **'bool'**:

# %%
value_mask = np.triu(pair_pivot.to_numpy()).astype(bool)

# %% [markdown]
# Теперь воспользуемся методом **mask** библиотеки **pandas** и наложим маску, полученную в предыдущем шаге, на значения **pair_pivot**, после чего заполним пустые значения нулями:

# %%
final_pairs = pair_pivot.mask(value_mask).fillna(0)

# %%
final_pairs
# Out:
# Товар                Абрикос вяленый  Абрикосы молдавские  Авокадо ХАСС  \
# Товар
# Абрикос вяленый                  0.0                  0.0           0.0
# Абрикосы молдавские             20.0                  0.0           0.0
# Авокадо ХАСС                    10.0                 37.0           0.0
# Авокадо стандарт                14.0                 46.0          25.0
# Алыча вяленая                    6.0                 23.0           7.0
# ...                              ...                  ...           ...
# Яблоки Фуджи                     5.0                 26.0          19.0
# Яблоки Чемпион                   5.0                 27.0          17.0
# Яблоки сезонные                  5.0                 23.0          13.0
# Яблоки сушеные                   7.0                 18.0          14.0
# Ягоды Годжи                      7.0                 29.0          16.0
#
# Товар                Авокадо стандарт  Алыча вяленая  Ананас Gold  \
# Товар
# Абрикос вяленый                   0.0            0.0          0.0
# Абрикосы молдавские               0.0            0.0          0.0
# Авокадо ХАСС                      0.0            0.0          0.0
# Авокадо стандарт                  0.0            0.0          0.0
# Алыча вяленая                    14.0            0.0          0.0
# ...                               ...            ...          ...
# Яблоки Фуджи                     17.0            9.0          6.0
# Яблоки Чемпион                   18.0            9.0          9.0
# Яблоки сезонные                  15.0            9.0         10.0
# Яблоки сушеные                    9.0           13.0          5.0
# Ягоды Годжи                      18.0            8.0          6.0
#
# Товар                Ананасовые кольца  Апельсины столовые  Арбуз  \
# Товар
# Абрикос вяленый                    0.0                 0.0    0.0
# Абрикосы молдавские                0.0                 0.0    0.0
# Авокадо ХАСС                       0.0                 0.0    0.0
# Авокадо стандарт                   0.0                 0.0    0.0
# Алыча вяленая                      0.0                 0.0    0.0
# ...                                ...                 ...    ...
# Яблоки Фуджи                       9.0                15.0   48.0
# Яблоки Чемпион                     9.0                18.0   41.0
# Яблоки сезонные                   12.0                22.0   52.0
# Яблоки сушеные                     3.0                 7.0   31.0
# Ягоды Годжи                        6.0                15.0   47.0
#
# Товар                Арбуз овальный  ...  Яблоки Гала  Яблоки Голден  \
# Товар                                ...
# Абрикос вяленый                 0.0  ...          0.0            0.0
# Абрикосы молдавские             0.0  ...          0.0            0.0
# Авокадо ХАСС                    0.0  ...          0.0            0.0
# Авокадо стандарт                0.0  ...          0.0            0.0
# Алыча вяленая                   0.0  ...          0.0            0.0
# ...                             ...  ...          ...            ...
# Яблоки Фуджи                   14.0  ...         11.0           11.0
# Яблоки Чемпион                 14.0  ...         13.0           11.0
# Яблоки сезонные                10.0  ...         16.0            8.0
# Яблоки сушеные                  6.0  ...          5.0            6.0
# Ягоды Годжи                     9.0  ...          7.0            8.0
#
# Товар                Яблоки Джонаголд  Яблоки Мутсу  Яблоки Симиренко  \
# Товар
# Абрикос вяленый                   0.0           0.0               0.0
# Абрикосы молдавские               0.0           0.0               0.0
# Авокадо ХАСС                      0.0           0.0               0.0
# Авокадо стандарт                  0.0           0.0               0.0
# Алыча вяленая                     0.0           0.0               0.0
# ...                               ...           ...               ...
# Яблоки Фуджи                     13.0          13.0              22.0
# Яблоки Чемпион                   11.0           7.0              11.0
# Яблоки сезонные                   3.0           7.0              10.0
# Яблоки сушеные                   10.0           9.0               6.0
# Ягоды Годжи                      13.0           6.0              12.0
#
# Товар                Яблоки Фуджи  Яблоки Чемпион  Яблоки сезонные  \
# Товар
# Абрикос вяленый               0.0             0.0              0.0
# Абрикосы молдавские           0.0             0.0              0.0
# Авокадо ХАСС                  0.0             0.0              0.0
# Авокадо стандарт              0.0             0.0              0.0
# Алыча вяленая                 0.0             0.0              0.0
# ...                           ...             ...              ...
# Яблоки Фуджи                  0.0             0.0              0.0
# Яблоки Чемпион               10.0             0.0              0.0
# Яблоки сезонные               5.0            10.0              0.0
# Яблоки сушеные               10.0             7.0              8.0
# Ягоды Годжи                   8.0            11.0             11.0
#
# Товар                Яблоки сушеные  Ягоды Годжи
# Товар
# Абрикос вяленый                 0.0          0.0
# Абрикосы молдавские             0.0          0.0
# Авокадо ХАСС                    0.0          0.0
# Авокадо стандарт                0.0          0.0
# Алыча вяленая                   0.0          0.0
# ...                             ...          ...
# Яблоки Фуджи                    0.0          0.0
# Яблоки Чемпион                  0.0          0.0
# Яблоки сезонные                 0.0          0.0
# Яблоки сушеные                  0.0          0.0
# Ягоды Годжи                     7.0          0.0
#
# [199 rows x 199 columns]

# %% [markdown]
# ### Приведение сводной таблицы к нормальному виду

# %%
pairs = final_pairs.stack().to_frame()\
    .reset_index(1)\
    .rename(columns={'Товар':'Second'})\
    .reset_index()\
    .rename(columns={'Товар':'First', 0:'Buying_frequency'})\
    .sort_values('Buying_frequency', ascending=False)

# %% [markdown]
# ### Проверка правильности работы алгоритма

# %% [markdown]
# Создадим запрос для двух конкретных товаров и посмотрим на частоту их встречаемости:

# %%
pairs.query("First == 'Яблоки Фуджи' and Second == 'Арбуз овальный'")
# Out:
#               First          Second  Buying_frequency
# 38615  Яблоки Фуджи  Арбуз овальный              14.0

# %% [markdown]
# В качестве контрольного значения используем данные полученные простым преобразованием исходного датафрейма, для этого сгруппируем его по чекам и товары в каждом чеке перечислим в отдельном списке:

# %%
test = df.groupby('id').agg({'Товар': lambda x: x.to_list()})
test['Товар'] = test['Товар'].astype(str)

# %% [markdown]
# Оставим только те чеки, которые содержат необходимую нам пару товаров и подсчитаем их количество:

# %% [markdown]
#  *так как мы используем метод **contains** необходимо использовать только точные названия товаров для проверки. Так **contains('Арбуз овальный')** в нашем случае, оставит лишь нужные значения, а **contains('Арбуз')** даст ложные значения, относящиеся также к другому товару*):

# %%
number_1 = test.loc[test['Товар'].str.contains('Яблоки Фуджи')]['Товар'].str.contains('Арбуз овальный').sum()

# %%
number_1
# Out:
# 14

# %% [markdown]
# Количество совпадений в итоговой таблице совпадает с количеством совпадений в исходных данных.

# %% [markdown]
# **Алгоритм работает правильно**.

# %% [markdown]
# Выводим 5 наиболее распространенных паттернов:

# %%
pairs.head()
# Out:
#                    First             Second  Buying_frequency
# 32948              Укроп  Огурцы Луховицкие             431.0
# 32962              Укроп           Петрушка             408.0
# 22495  Огурцы Луховицкие              Арбуз             345.0
# 22542  Огурцы Луховицкие            Кабачки             326.0
# 32902              Укроп              Кинза             303.0
